# %% [markdown]
# ## This will be the Main File for our testing adn things. We can read/write etc in this file

# %% [markdown]
# ## Step 1: Import the Appropriate Libaries and read in the data file

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Competition1_raw_data.xlsx', na_values='-')
print (df.head())
# Out:
#      I1                                  I2    I3  P(IPO)  P(H)  P(L)  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674    10.0   9.5   8.5
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834     8.0  10.0   8.0
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834     7.0  14.0  12.0
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834    11.5  16.0  14.0
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492    21.0  21.0  19.0
#
#      P(1Day)     C1   C2    C3  ...            C6       C7     T1       T2  \
# 0  11.870000  122.0  1.0  3.43  ...    10600000.0   51.345  470.0  12719.0
# 1   7.250000  259.0  0.0 -1.62  ...     2400000.0   25.936  791.0  21792.0
# 2   6.700000   90.0  1.0 -1.24  ...     5000000.0    7.378  201.0   5262.0
# 3  12.390000  209.0  1.0 -0.91  ...     4500000.0    8.526  328.0   8259.0
# 4  56.599998   80.0  1.0  0.07  ...     8250000.0  632.298  572.0  14830.0
#
#         T3     T4      T5    S1     S2     S3
# 0  11560.0  301.0   690.0  62.0  117.0  139.0
# 1  19585.0  510.0  1120.0  71.0  242.0  237.0
# 2   4785.0  128.0   325.0  61.0   33.0   60.0
# 3   7574.0  177.0   509.0  80.0   59.0  110.0
# 4  13176.0  336.0   720.0  67.0  149.0  167.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Step 2: Now Lets analyze the data that we have to work with

# %%
print('Checking the shape of our data \n')
print(df.shape)

print('Checking the data types we have \n')
print(df.dtypes)

print('Checking for missing values \n')
print(df.isna().sum())
# Out:
# Checking the shape of our data
#
# (682, 22)
# Checking the data types we have
#
# I1          object
# I2          object
# I3          object
# P(IPO)     float64
# P(H)       float64
# P(L)       float64
# P(1Day)    float64
# C1         float64
# C2         float64
# C3         float64
# C4         float64
# C5         float64
# C6         float64
# C7         float64
# T1         float64
# T2         float64
# T3         float64
# T4         float64
# T5         float64
# S1         float64
# S2         float64
# S3         float64
# dtype: object
# Checking for missing values
#
# I1          0
# I2          0
# I3          8
# P(IPO)      5
# P(H)       10
# P(L)       10
# P(1Day)    22
# C1         22
# C2         22
# C3         36
# C4         22
# C5          6
# C6          6
# C7         72
# T1          1
# T2          1
# T3          1
# T4          1
# T5          1
# S1          1
# S2          1
# S3          1
# dtype: int64

# %% [markdown]
# ## Step 3: Formatting our data
#
# In order to make sure our data matches with our data dictionary, we need to convert certain columns to certain values.

# %%
#need to convert these rows to the values as indicated by the Data Dictionary 

to_float = ['P(IPO)','P(H)', 'P(L)', 'P(1Day)', 'C1', 'C3', 'C4', 'C5', 'C6', 'C7', 'T1', 'T2', 'T3', 'T4', 'T5', 'S1', 'S2', 'S3']

for col in to_float:
    df[col]=pd.to_numeric(df[col], errors='coerce')
df['C2'] = df['C2'].astype('bool') 
print(df.dtypes)
# Out:
# I1          object
# I2          object
# I3          object
# P(IPO)     float64
# P(H)       float64
# P(L)       float64
# P(1Day)    float64
# C1         float64
# C2            bool
# C3         float64
# C4         float64
# C5         float64
# C6         float64
# C7         float64
# T1         float64
# T2         float64
# T3         float64
# T4         float64
# T5         float64
# S1         float64
# S2         float64
# S3         float64
# dtype: object

# %%
df.describe()
# Out:
#            P(IPO)        P(H)        P(L)      P(1Day)           C1  \
# count  677.000000  672.000000  672.000000   660.000000   660.000000
# mean    13.837666   15.481190   13.515045    25.934766   149.728788
# std      6.053731    6.653429    5.835646    73.234948   152.817467
# min      3.000000    0.000000    3.000000     0.000000    10.000000
# 25%     10.000000   12.500000   11.000000    11.000000    85.000000
# 50%     13.500000   15.000000   13.000000    14.845000   107.000000
# 75%     17.000000   17.000000   15.000000    20.485000   155.250000
# max     85.000000  135.000000  108.000000  1159.200562  2087.000000
#
#                 C3          C4            C5            C6            C7  \
# count   646.000000  660.000000  6.760000e+02  6.760000e+02    610.000000
# mean      1.788904    0.007282  4.935776e+07  1.241519e+07    500.459962
# std     162.666532    0.033318  1.043764e+08  2.512855e+07   1648.337634
# min    -786.239000   -0.162352  3.693227e+06  5.250000e+05      0.074000
# 25%      -0.852500   -0.013927  1.871417e+07  5.000000e+06     37.245750
# 50%       0.010000    0.009125  2.740018e+07  7.398704e+06    103.833000
# 75%       0.470000    0.031571  4.980786e+07  1.200000e+07    331.138000
# max    3864.500000    0.092896  2.138085e+09  4.212336e+08  30683.000000
#
#                 T1            T2            T3           T4            T5  \
# count   681.000000    681.000000    681.000000   681.000000    681.000000
# mean    465.634361  12758.606461  11395.844347   294.353891    679.220264
# std     175.741647   5449.644597   4839.670179   121.532637    472.914323
# min     132.000000      0.000000      0.000000     0.000000     -1.000000
# 25%     351.000000   9195.000000   8162.000000   213.000000    462.000000
# 50%     444.000000  12045.000000  10785.000000   279.000000    624.000000
# 75%     551.000000  15241.000000  13760.000000   354.000000    795.000000
# max    1750.000000  49056.000000  43952.000000  1058.000000  10277.000000
#
#                S1          S2          S3
# count  681.000000  681.000000  681.000000
# mean    68.421439  120.104258  144.759178
# std     39.096525   84.828959   69.276285
# min     -1.000000   20.000000   26.000000
# 25%     45.000000   73.000000  100.000000
# 50%     60.000000  100.000000  134.000000
# 75%     85.000000  142.000000  173.000000
# max    309.000000  944.000000  883.000000

# %%
## Creating Necessary Variables Y1, Y2, C3', C5', and C6'
## Code found on https://stackoverflow.com/questions/19913659/pandas-conditional-creation-of-a-series-dataframe-column
df['P(Mid)'] = (df['P(H)'] + df['P(L)']) / 2
df['Y1'] = np.where(df['P(IPO)'] < df['P(Mid)'], 1,0)
df['Y2'] = np.where(df['P(IPO)'] < df['P(1Day)'], 1,0)
df["C3'"] = np.where(df['C3'] > 0, 1, 0)
df["C5'"] = df['C5'] / df['C6']
df["C6'"] = np.where(df['P(IPO)'] > df['P(Mid)'], ((df['P(IPO)'] - df['P(Mid)']) / df['P(Mid)']) * 100,0)

# %%
df
# Out:
#        I1                                     I2    I3  P(IPO)  P(H)  P(L)  \
# 0    AATI     ADVANCED ANALOGIC TECHNOLOGIES INC  3674    10.0   9.5   8.5
# 1    ABPI        ACCENTIA BIOPHARMACEUTICALS INC  2834     8.0  10.0   8.0
# 2    ACAD             ACADIA PHARMACEUTICALS INC  2834     7.0  14.0  12.0
# 3    ACHN          ACHILLION PHARMACEUTICALS INC  2834    11.5  16.0  14.0
# 4    ACLI        AMERICAN COMMERCIAL LINES INC.   4492    21.0  21.0  19.0
# 5    ACOM                     Ancestry.com Inc.   7379    13.5  14.5  12.5
# 6    ACOR                ACORDA THERAPEUTICS INC  2836     6.0  13.0  11.0
# 7    ACRX             ACELRX PHARMACEUTICALS INC  2834     5.0  14.0  12.0
# 8    ACTV                     ACTIVE NETWORK INC  7372    15.0  18.0  16.0
# 9     ACW                          ACCURIDE CORP  3714     9.0  19.0  17.0
# 10   ADKU             ADCARE HEALTH SYSTEMS, INC   NaN     NaN   NaN   NaN
# 11   ADLS  Advanced Life Sciences Holdings, Inc.  2854     5.0   9.0   8.0
# 12   ADZA                  ADEZA BIOMEDICAL CORP  2835    16.0  16.0  14.0
# 13   AFFY                            AFFYMAX INC  2834    25.0  24.0  22.0
# 14   AGAM            AGA Medical Holdings, Inc.   3845    14.5  16.0  15.0
# 15     AH                           R1 RCM INC.   7389    12.0  16.0  14.0
# 16   AHII           ANIMAL HEALTH HOLDINGS, INC.  5047    11.0  12.0  10.0
# 17   AIMC         Altra Industrial Motion Corp.   3568    13.5  16.0  14.0
# 18   AIRV                            AIRVANA INC  3661     7.0  10.0   8.0
# 19   ALGT                   Allegiant Travel CO   4512    18.0  17.0  15.0
# 20   ALIM                  ALIMERA SCIENCES INC   2834    11.0  17.0  15.0
# 21    ALJ                 Alon USA Energy, Inc.   2911    16.0  16.0  14.0
# 22   ALLI                  ALLION HEALTHCARE INC  8099    13.0  14.0  12.0
# 23   ALNY          ALNYLAM PHARMACEUTICALS, INC.  2834     6.0   8.0   6.0
# 24   ALTU            Altus Pharmaceuticals Inc.   2836    15.0  16.0  14.0
# 25   ALXA           Alexza Pharmaceuticals Inc.   2834     8.0  12.0  10.0
# 26   AMBA                         AMBARELLA INC   3674     6.0  11.0   9.0
# 27   AMIS                      AMIS HOLDINGS INC  3674    20.0  20.0  18.0
# 28   AMRC                         Ameresco, Inc.  4931    10.0  16.0  14.0
# 29   ANAC           Anacor Pharmaceuticals, Inc.  2834     5.0  18.0  16.0
# ..    ...                                    ...   ...     ...   ...   ...
# 652  WCAA                         WCA WASTE CORP  4953     9.5  11.0   9.0
# 653   WCG           WELLCARE HEALTH PLANS, INC.   6324    17.0  16.0  14.0
# 654  WCRX                   Warner Chilcott plc   2834    15.0  19.0  17.0
# 655  WDAY                         Workday, Inc.   7372    28.0  26.0  24.0
# 656  WIFI                    BOINGO WIRELESS INC  7389    13.5  14.0  12.0
# 657  WLDN                   Willdan Group, Inc.   8711    10.0  11.0   9.0
# 658   WLK                 WESTLAKE CHEMICAL CORP  2869    14.5  18.5  16.5
# 659   WLL                WHITING PETROLEUM CORP   1311    15.5  16.0  14.0
# 660  WLSC    WILLIAMS SCOTSMAN INTERNATIONAL INC  7359    16.0  18.0  16.0
# 661   WMG              Warner Music Group Corp.   7929    17.0  24.0  22.0
# 662   WNR                 Western Refining, Inc.  2911    17.0  17.0  15.0
# 663  WOLF               Great Wolf Resorts, Inc.  7011    17.0  17.0  15.0
# 664  WSSI                  VISUAL SCIENCES, INC.  7372     8.5   9.0   8.0
# 665  WSTC                              WEST CORP  7389    20.0  25.0  22.0
# 666   WTI                      W&T OFFSHORE INC   1311    19.0  18.5  16.5
# 667  XCYT          Cyclacel Pharmaceuticals, Inc  2834     8.0  15.0  13.0
# 668  XGEN                          XENOGEN CORP   2835     7.0  11.0   9.0
# 669  XPRT                             LECG CORP   8742    17.0  16.0  14.0
# 670   XRM                XERIUM TECHNOLOGIES INC  2221    12.0  16.0  14.0
# 671  XTNT                              XTENT INC  3841    16.0  18.0  16.0
# 672  XTXI                 ENLINK MIDSTREAM, INC.  1311    19.5  18.5  16.5
# 673     Z                             ZILLOW INC  7389    20.0  14.0  12.0
# 674   ZBB                           EnSync, Inc.  4911     6.0   6.5   5.5
# 675  ZGNX                          ZOGENIX, INC.  2834     4.0  14.0  12.0
# 676  ZINC                Horsehead Holding Corp   3341    18.0  20.0  18.0
# 677   ZIP                             ZIPCAR INC  7514    18.0  16.0  14.0
# 678  ZLTQ                 Zeltiq Aesthetics Inc   3845    13.0  16.0  14.0
# 679  ZSTN             ZST Digital Networks, Inc.  3663     8.0   8.5   7.5
# 680  ZUMZ                            Zumiez Inc   5600    19.0  17.0  15.0
# 681    ZZ                             SEALY CORP  2510    16.0  16.0  14.0
#
#         P(1Day)      C1     C2       C3    ...          T5     S1     S2  \
# 0     11.870000   122.0   True     3.43    ...       690.0   62.0  117.0
# 1      7.250000   259.0  False    -1.62    ...      1120.0   71.0  242.0
# 2      6.700000    90.0   True    -1.24    ...       325.0   61.0   33.0
# 3     12.390000   209.0   True    -0.91    ...       509.0   80.0   59.0
# 4     56.599998    80.0   True     0.07    ...       720.0   67.0  149.0
# 5     14.200000    94.0   True     0.06    ...       815.0   62.0   96.0
# 6      6.720000   128.0   True    -1.87    ...       698.0   82.0  106.0
# 7      4.550000    91.0  False    -0.74    ...        -1.0   55.0  120.0
# 8     15.900000   100.0   True    -0.51    ...       917.0   58.0  124.0
# 9      0.000000   106.0   True     1.49    ...       459.0   81.0   90.0
# 10          NaN     NaN   True      NaN    ...       263.0   51.0   65.0
# 11     6.000000    99.0   True  -398.10    ...       385.0   29.0   41.0
# 12    19.700001   126.0   True     0.27    ...       259.0   21.0   43.0
# 13    33.880001   140.0   True    -2.19    ...       726.0   81.0  118.0
# 14    14.600000   488.0   True     0.18    ...       909.0   98.0  256.0
# 15    13.550000   233.0   True     0.17    ...       649.0   98.0   92.0
# 16    12.450000   125.0   True     0.31    ...       336.0   36.0   33.0
# 17    14.290000    77.0   True     0.14    ...       603.0   72.0  134.0
# 18     7.170000    92.0   True     1.18    ...       523.0   54.0   75.0
# 19    25.100000   207.0   True     0.63    ...       429.0   52.0   78.0
# 20    11.000000   174.0   True    -1.43    ...       768.0   66.0  136.0
# 21    17.250000    78.0   True     0.67    ...       675.0   57.0   73.0
# 22    16.500000    68.0   True    -0.86    ...       308.0   29.0   93.0
# 23     6.010000    91.0   True   -29.64    ...       384.0   58.0   39.0
# 24    16.820000   101.0   True    -1.39    ...       473.0   63.0   51.0
# 25    85.099983    76.0   True   -19.20    ...       453.0   36.0   85.0
# 26     6.060000   488.0   True     0.38    ...       777.0   91.0   88.0
# 27    20.100000    40.0   True    -0.41    ...       809.0   46.0  181.0
# 28    10.170000   113.0   True     0.50    ...       898.0  125.0  164.0
# 29     5.090000    75.0   True    -0.93    ...       626.0  103.0  102.0
# ..          ...     ...    ...      ...    ...         ...    ...    ...
# 652    8.590000   106.0  False     0.63    ...       418.0   55.0  127.0
# 653   19.530000   139.0   True     0.66    ...       629.0   47.0  104.0
# 654   14.950000   104.0   True    -2.84    ...      1054.0   91.0  199.0
# 655   48.689999    43.0   True      NaN    ...       722.0   57.0   70.0
# 656   12.100000   110.0   True     0.49    ...       592.0   37.0   83.0
# 657   10.560000   104.0  False    -0.21    ...       378.0   17.0   61.0
# 658    7.325000    79.0   True     0.30    ...       486.0   67.0  112.0
# 659    8.135000   118.0   True  3864.50    ...       391.0   76.0   97.0
# 660   15.980000   144.0   True    -0.55    ...       446.0   33.0  100.0
# 661   16.400000    61.0   True    -6.43    ...      1270.0  117.0  371.0
# 662   18.590000   114.0   True     3.69    ...       559.0   47.0   83.0
# 663   21.000000   125.0   True    -0.16    ...       586.0   99.0   91.0
# 664    9.040000   124.0  False    -0.86    ...       390.0   32.0   66.0
# 665   18.860001  1267.0   True     8.32    ...       731.0   69.0  152.0
# 666   18.500000   270.0   True     2.82    ...       631.0   67.0  114.0
# 667  511.700000   158.0  False   -12.40    ...       322.0   18.0   44.0
# 668    7.500000   105.0   True   -33.89    ...       514.0   32.0  134.0
# 669   21.030001    81.0   True    -1.41    ...       395.0   16.0   46.0
# 670  239.999940   389.0   True   -24.75    ...       751.0  114.0  178.0
# 671   16.480000   178.0   True    -1.60    ...       357.0   41.0   67.0
# 672    8.466666    75.0  False      NaN    ...       843.0   65.0  139.0
# 673   35.770000    93.0   True    -0.53    ...       705.0   89.0   87.0
# 674   29.000000   234.0  False    -0.60    ...       394.0   38.0   60.0
# 675         NaN     NaN   True      NaN    ...       790.0   71.0  146.0
# 676   18.600000   119.0   True     2.70    ...       489.0   57.0   84.0
# 677   28.000000   317.0   True    -0.37    ...       676.0   87.0  106.0
# 678   15.500000    98.0   True    -0.41    ...       784.0   70.0  126.0
# 679    7.520000   112.0  False     0.60    ...       435.0   38.0   82.0
# 680   12.435000    78.0   True     0.20    ...       306.0   48.0   38.0
# 681    8.340122   281.0   True     0.76    ...       636.0   94.0  103.0
#
#         S3  P(Mid)  Y1  Y2  C3'        C5'        C6'
# 0    139.0     9.0   0   1    1   3.864345  11.111111
# 1    237.0     9.0   1   0    0  12.028832   0.000000
# 2     60.0    13.0   1   0    0   3.369134   0.000000
# 3    110.0    15.0   1   1    0   3.299697   0.000000
# 4    167.0    20.0   0   1    1   3.726269   5.000000
# 5    181.0    13.5   0   1    1   5.724394   0.000000
# 6    135.0    12.0   1   1    0   3.463095   0.000000
# 7    122.0    13.0   1   0    0   2.421469   0.000000
# 8    234.0    17.0   1   1    0   4.816591   0.000000
# 9    147.0    18.0   1   0    1   3.056608   0.000000
# 10    74.0     NaN   0   0    0        NaN   0.000000
# 11    70.0     8.5   1   1    0   2.546686   0.000000
# 12    80.0    15.0   0   1    1   4.237291   6.666667
# 13   138.0    23.0   0   1    0   3.867637   8.695652
# 14   172.0    15.5   1   1    1   3.638220   0.000000
# 15   155.0    15.0   1   1    1   9.001571   0.000000
# 16    83.0    11.0   0   1    1   2.062121   0.000000
# 17   133.0    15.0   1   1    1   2.308759   0.000000
# 18   117.0     9.0   1   1    1   7.634886   0.000000
# 19    91.0    16.0   0   1    1   3.809187  12.500000
# 20   182.0    16.0   1   0    0   4.740619   0.000000
# 21    88.0    15.0   0   1    1   4.431482   6.666667
# 22    97.0    13.0   0   1    0   2.973739   0.000000
# 23   100.0     7.0   1   1    0   3.856666   0.000000
# 24    93.0    15.0   0   1    0   3.000278   0.000000
# 25   119.0    11.0   1   1    0   4.117524   0.000000
# 26   237.0    10.0   1   1    1   4.318244   0.000000
# 27   167.0    19.0   0   1    0   2.395495   5.263158
# 28   184.0    15.0   1   1    1   4.645753   0.000000
# 29   162.0    17.0   1   1    0   2.217852   0.000000
# ..     ...     ...  ..  ..  ...        ...        ...
# 652   89.0    10.0   1   0    1   1.620918   0.000000
# 653  163.0    15.0   0   1    1   5.054876  13.333333
# 654  226.0    18.0   1   0    0   3.548984   0.000000
# 655  129.0    25.0   0   1    0   7.045716  12.000000
# 656  128.0    13.0   0   0    1   5.637452   3.846154
# 657   77.0    10.0   0   1    0   2.314703   0.000000
# 658  103.0    17.5   1   0    1   5.377949   0.000000
# 659   98.0    15.0   0   0    1   1.249200   3.333333
# 660  141.0    17.0   1   0    0   2.526391   0.000000
# 661  239.0    23.0   1   0    0   4.553691   0.000000
# 662  108.0    16.0   0   1    1   2.953022   6.250000
# 663   90.0    16.0   0   1    0   2.011593   6.250000
# 664   75.0     8.5   0   1    0   3.111096   0.000000
# 665  164.0    23.5   1   0    1   3.921146   0.000000
# 666  141.0    17.5   0   0    1   5.212790   8.571429
# 667   67.0    14.0   1   1    0   3.517192   0.000000
# 668  121.0    10.0   1   1    0   3.494590   0.000000
# 669   92.0    15.0   0   1    0   2.740591  13.333333
# 670  173.0    15.0   1   1    0   3.269683   0.000000
# 671  111.0    17.0   1   1    0   4.850278   0.000000
# 672  174.0    17.5   0   0    0   5.088182  11.428571
# 673  171.0    13.0   0   1    0   2.752257  53.846154
# 674   59.0     6.0   0   1    0   2.577852   0.000000
# 675  190.0    13.0   1   0    0   2.397414   0.000000
# 676  112.0    19.0   1   1    1   6.994796   0.000000
# 677  173.0    15.0   0   1    0   3.963872  20.000000
# 678  173.0    15.0   1   1    0   4.679726   0.000000
# 679   90.0     8.0   0   0    1   3.673544   0.000000
# 680  100.0    16.0   0   0    1   4.217684  18.750000
# 681  158.0    15.0   0   0    1   3.240507   6.666667
#
# [682 rows x 28 columns]
